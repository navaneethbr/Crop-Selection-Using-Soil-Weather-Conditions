# %%
import pandas as pd
import numpy as np
df=pd.read_csv("D:\semester 6\Predictive Analytics\Project\Crop_recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %% [markdown]
# # Checking for null values

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# # Data Visualization and Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import *

# %%
plt.figure(figsize=(25,20))
plt.subplot(4, 3, 1)
sns.distplot(df['N'],color="green",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 2)
sns.distplot(df['P'],color="blue",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 3)
sns.distplot(df['K'],color="green",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 4)
sns.distplot(df['temperature'],color="green",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 5)
sns.distplot(df['ph'],color="blue",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 6)
sns.distplot(df['humidity'],color="blue",bins=20, fit=norm,hist_kws={'alpha':0.2})
plt.subplot(4, 3, 7)
sns.distplot(df['rainfall'],color="blue",bins=20, fit=norm,hist_kws={'alpha':0.2})
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='label',data=df, palette="plasma_r")
# Out:
# <AxesSubplot:xlabel='count', ylabel='label'>

# %%
df1=df.iloc[:,:4]
target=df['label']
df1=pd.concat([df1,target],axis='columns')
df2=df.iloc[:,4:8]

# %%
sns.pairplot(df1, hue = 'label')

# %%
sns.pairplot(df2, hue = 'label')

# %%
plt.figure(figsize=(20,15))
plt.subplot(2, 2, 1)
sns.boxplot(y='label',x='N',data=df)
plt.subplot(2, 2, 2)
sns.boxplot(y='label',x='P',data=df)
plt.subplot(2, 2, 3)
sns.boxplot(y='label',x='K',data=df)
# Out:
# <AxesSubplot:xlabel='K', ylabel='label'>

# %%
plt.figure(figsize=(20,15))
plt.subplot(2, 2, 1)
sns.boxplot(y='label',x='temperature',data=df)
plt.subplot(2, 2, 2)
sns.boxplot(y='label',x='humidity',data=df)
plt.subplot(2, 2, 3)
sns.boxplot(y='label',x='ph',data=df)
plt.subplot(2, 2, 4)
sns.boxplot(y='label',x='rainfall',data=df)
# Out:
# <AxesSubplot:xlabel='rainfall', ylabel='label'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(df,'rainfall')

# %%
df1=pd.DataFrame()

# %%
df1['N_sqaure']=df.N**(1/2)
plot_data(df1,'N_sqaure')

# %%
df1['P_sqaure']=df.P**(1/2)
plot_data(df1,'P_sqaure')

# %%
df1['K_log']=np.log(df['K'])
plot_data(df1,'K_log')

# %%
df1['temperature']=df['temperature']

# %%
df1['humidity_Boxcox'],parameters=stat.boxcox(df['humidity'])
plot_data(df1,'humidity_Boxcox')

# %%
df1['ph']=df['ph']

# %%
df1['rainfall_Boxcox'],parameters=stat.boxcox(df['rainfall'])
plot_data(df1,'rainfall_Boxcox')

# %%
df1['label']=df['label']

# %%
df1
# Out:
#        N_sqaure  P_sqaure     K_log  temperature  humidity_Boxcox        ph  \
# 0      9.486833  6.480741  3.761200    20.879744      5334.394104  6.502985
# 1      9.219544  7.615773  3.713572    21.770462      5105.163834  7.038096
# 2      7.745967  7.416198  3.784190    23.004459      5378.303903  7.840207
# 3      8.602325  5.916080  3.688879    26.491096      5083.476901  6.980401
# 4      8.831761  6.480741  3.737670    20.130175      5279.726241  7.628473
# ...         ...       ...       ...          ...              ...       ...
# 2195  10.344080  5.830952  3.465736    26.774637      3412.983951  6.780064
# 2196   9.949874  3.872983  3.295837    27.417112      2435.836248  6.086922
# 2197  10.862780  5.744563  3.401197    24.131797      3501.955138  6.362608
# 2198  10.816654  5.656854  3.526361    26.272418      2043.294845  6.758793
# 2199  10.198039  4.242641  3.401197    23.603016      2791.118159  6.779833
#
#       rainfall_Boxcox   label
# ...

# %%
c=df1.label.astype('category')
targets = dict(enumerate(c.cat.categories))
df1['target']=c.cat.codes

# %%
df1
# Out:
#        N_sqaure  P_sqaure     K_log  temperature  humidity_Boxcox        ph  \
# 0      9.486833  6.480741  3.761200    20.879744      5334.394104  6.502985
# 1      9.219544  7.615773  3.713572    21.770462      5105.163834  7.038096
# 2      7.745967  7.416198  3.784190    23.004459      5378.303903  7.840207
# 3      8.602325  5.916080  3.688879    26.491096      5083.476901  6.980401
# 4      8.831761  6.480741  3.737670    20.130175      5279.726241  7.628473
# ...         ...       ...       ...          ...              ...       ...
# 2195  10.344080  5.830952  3.465736    26.774637      3412.983951  6.780064
# 2196   9.949874  3.872983  3.295837    27.417112      2435.836248  6.086922
# 2197  10.862780  5.744563  3.401197    24.131797      3501.955138  6.362608
# 2198  10.816654  5.656854  3.526361    26.272418      2043.294845  6.758793
# 2199  10.198039  4.242641  3.401197    23.603016      2791.118159  6.779833
#
#       rainfall_Boxcox   label  target
# ...

# %%
X=df1.iloc[:,:-2]
y=df1.iloc[:,8:9]

# %%
X
# Out:
#        N_sqaure  P_sqaure     K_log  temperature  humidity_Boxcox        ph  \
# 0      9.486833  6.480741  3.761200    20.879744      5334.394104  6.502985
# 1      9.219544  7.615773  3.713572    21.770462      5105.163834  7.038096
# 2      7.745967  7.416198  3.784190    23.004459      5378.303903  7.840207
# 3      8.602325  5.916080  3.688879    26.491096      5083.476901  6.980401
# 4      8.831761  6.480741  3.737670    20.130175      5279.726241  7.628473
# ...         ...       ...       ...          ...              ...       ...
# 2195  10.344080  5.830952  3.465736    26.774637      3412.983951  6.780064
# 2196   9.949874  3.872983  3.295837    27.417112      2435.836248  6.086922
# 2197  10.862780  5.744563  3.401197    24.131797      3501.955138  6.362608
# 2198  10.816654  5.656854  3.526361    26.272418      2043.294845  6.758793
# 2199  10.198039  4.242641  3.401197    23.603016      2791.118159  6.779833
#
#       rainfall_Boxcox
# 0            9.991829
# ...

# %%
y
# Out:
#       target
# 0         20
# 1         20
# 2         20
# 3         20
# 4         20
# ...      ...
# 2195       5
# 2196       5
# 2197       5
# 2198       5
# 2199       5
#
# [2200 rows x 1 columns]

# %%
df.corr()
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((1540, 7), (660, 7))

# %%
X_train.corr()
# Out:
#                  N_sqaure  P_sqaure     K_log  temperature  humidity_Boxcox  \
# N_sqaure         1.000000 -0.182353  0.046692     0.051955         0.119087
# P_sqaure        -0.182353  1.000000  0.470481    -0.113392        -0.210479
# K_log            0.046692  0.470481  1.000000    -0.091384         0.245246
# temperature      0.051955 -0.113392 -0.091384     1.000000         0.128974
# humidity_Boxcox  0.119087 -0.210479  0.245246     0.128974         1.000000
# ph               0.129307 -0.103901 -0.159228    -0.017830        -0.019133
# rainfall_Boxcox  0.002880  0.018936  0.019561    -0.069442         0.034046
#
#                        ph  rainfall_Boxcox
# N_sqaure         0.129307         0.002880
# P_sqaure        -0.103901         0.018936
# K_log           -0.159228         0.019561
# temperature     -0.017830        -0.069442
# humidity_Boxcox -0.019133         0.034046
# ph               1.000000        -0.134263
# rainfall_Boxcox -0.134263         1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 0

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaling=StandardScaler()

# %%
X_train_scaled=scaling.fit_transform(X_train)
X_train_scaled
# Out:
# array([[ 1.10457792,  0.23206322,  0.27056449, ...,  0.43176193,
#          1.19711643,  1.48490536],
#        [ 0.8960407 , -0.86459708,  0.53046632, ...,  0.77334812,
#         -0.5276221 , -1.1034339 ],
#        [-1.60505803, -1.99093168, -2.12792713, ...,  1.02441416,
#          0.30891807,  0.37526658],
#        ...,
#        [-0.21682734,  0.46023735, -1.10770842, ..., -0.59486604,
#          0.03378207, -0.49701993],
#        [-0.10022748,  0.48773108, -0.53552175, ..., -0.31856778,
#          1.5967449 , -1.3511775 ],
#        [-0.9876492 , -1.00131304, -1.79151169, ...,  1.02582993,
#          0.09051998,  0.37248173]])

# %%
X_test_scaled=scaling.fit_transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 1.34420054, -1.41437929,  0.48218418, ...,  0.74913454,
#         -0.04788974, -0.81146903],
#        [ 1.08658266, -1.537858  ,  0.36864937, ...,  0.60426284,
#         -0.14088175, -1.16306414],
#        [-1.02433762,  1.8147042 ,  2.39007536, ...,  0.49127624,
#         -0.37024048, -0.4240668 ],
#        ...,
#        [-0.75837477,  1.83488436,  2.39676643, ...,  0.31091803,
#          0.03669299, -0.6619149 ],
#        [ 0.28888086,  0.56252703,  0.53558823, ...,  1.13973173,
#          0.15893839,  0.80641234],
#        [-0.08392003,  0.30913306,  1.03427717, ..., -1.96591621,
#          0.87948871, -0.08597219]])

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
clf_svm= SVC(random_state=0)

# %%
clf_svm.fit(X_train_scaled, y_train.values.ravel())
# Out:
# SVC(random_state=0)

# %%
svc_linear = SVC(kernel = 'linear').fit(X_train_scaled, y_train.values.ravel())
print("Linear Kernel Accuracy: ",svc_linear.score(X_test_scaled,y_test))

svc_poly = SVC(kernel = 'rbf').fit(X_train_scaled, y_train.values.ravel())
print("Rbf Kernel Accuracy: ", svc_poly.score(X_test_scaled,y_test))

svc_poly = SVC(kernel = 'poly').fit(X_train_scaled, y_train.values.ravel())
print("Poly Kernel Accuracy: ", svc_poly.score(X_test_scaled,y_test))
# Out:
# Linear Kernel Accuracy:  0.9833333333333333
# Rbf Kernel Accuracy:  0.9833333333333333
# Poly Kernel Accuracy:  0.953030303030303

# %%
from sklearn.metrics import precision_recall_fscore_support, classification_report, confusion_matrix, plot_confusion_matrix
from matplotlib import pyplot as plt

# %%
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,clf_svm.predict(X_test_scaled))
df_cm = pd.DataFrame(mat, list(targets.values()), list(targets.values()))
sns.set(font_scale=1.0) # for label size
plt.figure(figsize = (12,8))
sns.heatmap(df_cm, annot=True, annot_kws={"size": 12},cmap="terrain")
# Out:
# <AxesSubplot:>

# %%
pred=clf_svm.predict(X_test_scaled)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       1.00      1.00      1.00        30
#            2       1.00      0.97      0.98        31
#            3       1.00      1.00      1.00        34
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        29
#            6       0.97      1.00      0.98        28
#            7       1.00      1.00      1.00        30
#            8       0.86      0.97      0.91        31
#            9       0.93      1.00      0.96        26
#           10       0.92      1.00      0.96        22
#           11       1.00      0.96      0.98        27
#           12       1.00      1.00      1.00        28
#           13       1.00      0.97      0.99        36
#           14       1.00      1.00      1.00        29
#           15       1.00      1.00      1.00        30
# ...

# %%
clf_svm.score(X_test_scaled, y_test)
# Out:
# 0.9833333333333333

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

parameters = {'C': np.logspace(-3, 2, 6).tolist(), 'gamma': np.logspace(-3, 2, 6).tolist()}
# 'degree': np.arange(0,5,1).tolist(), 'kernel':['linear','rbf','poly']

model = GridSearchCV(estimator = SVC(kernel="linear"), param_grid=parameters, n_jobs=-1, cv=4)
model.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GridSearchCV(cv=4, estimator=SVC(kernel='linear'), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
#                          'gamma': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]})

# %%
model.best_score_
model.best_params_
# Out:
# {'C': 0.1, 'gamma': 0.001}

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train.values.ravel())
knn.score(X_test_scaled, y_test.values.ravel())
# Out:
# 0.9772727272727273

# %%
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,knn.predict(X_test_scaled))
df_cm = pd.DataFrame(mat, list(targets.values()), list(targets.values()))
sns.set(font_scale=1.0) # for label size
plt.figure(figsize = (12,8))
sns.heatmap(df_cm, annot=True, annot_kws={"size": 12},cmap="terrain")
# Out:
# <AxesSubplot:>

# %%
k_range = range(1,11)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train_scaled, y_train.values.ravel())
    scores.append(knn.score(X_test_scaled, y_test.values.ravel()))

plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, linestyle="dashed")
plt.ylim(0.96,0.99)
plt.xticks([i for i in range(1,11)]);

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=42).fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.9803030303030303

# %%
plt.figure(figsize=(10,4), dpi=80)
c_features = len(X_train.columns)
plt.barh(range(c_features), clf.feature_importances_)
plt.xlabel("Feature importance")
plt.ylabel("Feature name")
plt.yticks(np.arange(c_features), X_train.columns)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=4,n_estimators=100,random_state=42).fit(X_train, y_train.values.ravel())

print('RF Accuracy on training set: {:.2f}'.format(clf.score(X_train, y_train.values.ravel())))
print('RF Accuracy on test set: {:.2f}'.format(clf.score(X_test, y_test)))
# Out:
# RF Accuracy on training set: 0.94
# RF Accuracy on test set: 0.92
